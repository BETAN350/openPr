# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(245, 245, 245, 0.95); color: #2c2c2c; padding: 18px 24px; margin: 16px 0; border-left: 5px solid #666; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.1); backdrop-filter: blur(1.5px);">
#
#
# **Тимур, привет! Рад с тобой познакомиться 😊**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍  Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝  Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. **Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (Сode/Markdown)**.</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента</b><br><br>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# К сожалению отсутствуют заголовок, краткое описание задачи, ход и цель исследования. Хорошо структурированное вступление делает проект более профессиональным, понятным и ценным для читателя и заказчика.
#
# Вот краткий пример на основе проекта: Исследовательский анализ данных.
#
# ![%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg](attachment:%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg)
#
#
# </div>

# %% [markdown]
#
# **Заголовок:** аналитиз популярного сервиса аренды самокатов
#
# **Описание проекта**. Есть данные о некоторых пользователях из нескольких городов, а также об их поездках. Проанализировав данные и проверив некоторые гипотезы, можем понять как помочь вырасти бизнессу.
#
#
# **Цель исследования**: Определить средний возраст, количество поездок для различных групп и посмотреть на их распределения и зависимости, обработка аномалий
#
# **Ход исследования**:
#
# 1. Загрузка данных
# 2. Предобработка данных( Выявление дубликатов, приведение типов)
# 3. Исследовательский анализ ( Визуализация информации )
# 4. Объединение всех таблиц
# 5. Подсчет выручки
# 6. Проверка гипотез

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> сделал вступление

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
users= pd.read_csv('/datasets/users_go.csv') # df данных пользователя

# %%
users.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
rides= pd.read_csv('/datasets/rides_go.csv') # df с логами поездок

# %%
rides.head()

# %%
subs= pd.read_csv('/datasets/subscriptions_go.csv')# условия подписки

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# Вывод: Изучив все три таблицы можно увидеть, что среди 18068 строк в rides и 1565 строк в users нет ни одного пропуска, однако нужно поменять тип данных в столбце date таблицы rides

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Здесь у нас заканчивается вводная часть ознакомления с данными. Основная информация получена. Было бы неплохо также привести небольшое заключение по объему данных и основных ошибках, которые уже были обнаружены на этой стадии (типы данных, пропуски, названия колонок и др).
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# *Приведем столбец date к типу datetime64*:

# %%
rides['date'] = pd.to_datetime(rides['date'], format = '%Y-%m-%d')

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍 При чтении файла можно указать параметр <code>parse_dates: parse_dates=['date']</code>. Тогда пандас автоматически переведет список столбцов в даты.
#
# Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB

# %%
rides.head()
# Out:
#    user_id     distance   duration       date
# 0        1  4409.919140  25.599769 2021-01-01
# 1        1  2617.592153  15.816871 2021-01-18
# 2        1   754.159807   6.232113 2021-04-20
# 3        1  2694.783254  18.511000 2021-08-11
# 4        1  4028.687306  26.265803 2021-08-28

# %% [markdown]
# *Добавим столбец date_month с номером месяца из date*

# %%
rides['date_month'] =  pd.DatetimeIndex(rides['date']).month

# %% [markdown]
# *Проверим наши датафреймы rides и users на пропуски:*

# %%
rides.isna().sum()
# Out:
# user_id       0
# distance      0
# duration      0
# date          0
# date_month    0
# dtype: int64

# %%
users.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %% [markdown]
# в датафрейме нет пропущенных значений

# %%
rides.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 31

# %%
users.drop_duplicates().reset_index()
# Out:
#       index  user_id        name  age            city subscription_type
# 0         0        1        Кира   22          Тюмень             ultra
# 1         1        2   Станислав   31            Омск             ultra
# 2         2        3     Алексей   20          Москва             ultra
# 3         3        4  Константин   26  Ростов-на-Дону             ultra
# 4         4        5       Адель   28            Омск             ultra
# ...     ...      ...         ...  ...             ...               ...
# 1529   1529     1530   Ростислав   29            Сочи              free
# 1530   1530     1531      Никита   25       Пятигорск              free
# 1531   1531     1532     Алексей   26          Тюмень              free
# 1532   1532     1533      Степан   22       Краснодар              free
# 1533   1533     1534     Альберт   25       Краснодар              free
#
# [1534 rows x 6 columns]

# %% [markdown]
# В таблице users получилось 31 явных дубликата

# %%
# Код ревьюера
users.duplicated().sum()
# Out:
# 31

# %%
users = users.drop_duplicates().reset_index()

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Обрати, пожалуйста, внимание, что дубликаты никуда не делись. Переменная не перезаписана.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# ✍
# Тимур, такой способ удаления дубликатов у тебя не сработает, потому что ты вызываешь метод drop_duplicates(), но не сохраняешь результат ни в переменную, ни обратно в датафрейм.
#
# Метод по умолчанию возвращает новый датафрейм без дубликатов, но сам users остаётся без изменений. То же самое с reset_index() — он тоже не меняет данные "на месте".
#
# Чтобы всё действительно применилось, результат нужно явно сохранить, иначе эти действия просто ничего не изменят в твоих данных.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.4</b><br><br>
# 👍
#
# </div>

# %%
# Код ревьюера
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В предобработке данных мы сменили необходимый тип данных date, добавили столбец с месяцем и удалили дубликаты с таблицы  users

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Замечания:
#
#
# * Отсутствует проверка явных дубликатов, а это основа предобработки данных.
#
#
# * К сожалению отсутствует промежуточный вывод о проделанной работе в разделе. Дополни, пожалуйста.
# </div>

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# 3.1
#
# *Узнаем о пользователях с разных городов*

# %%
users['city'].value_counts()
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %%
users['city'].hist(figsize=(10,6),bins = 15)
plt.title('Количество пользователей по городам')
plt.xlabel('Город')
plt.ylabel('Количество пользователей')
# Out:
# Text(0, 0.5, 'Количество пользователей')

# %%
print('Медианное кол-во пользователей в городах - ', users['city'].value_counts().median())
print('Среднее арифм. кол-во пользователей в городах - ', users['city'].value_counts().mean())
# Out:
# Медианное кол-во пользователей в городах -  191.0
# Среднее арифм. кол-во пользователей в городах -  191.75

# %% [markdown]
# После изучения значений и визуализации графиков, можно понять, что среднее количество пользователей в городах около 195.
#
# Наименьшее кол-во пользователей в Москве - 172, наибольшее в Пятигорске - 226

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Не могу не отметить отличную визуализацию. Здорово, что оформляешь графики правильно.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝 Можно повернуть либо сам график на 90 градусов, либо подписи к оси X. А также применить сортировку.
# </div>

# %% [markdown]
# 3.2
#
# *Изучим соотношение пользователей с подпиской и без нее*

# %%
users.query('subscription_type == "ultra"').count()['age']/users.count()['age']
# Out:
# 0.4556714471968709

# %%
users['subscription_type'].value_counts().plot(kind = 'pie', autopct='%.1f%%', figsize=(10,6))
plt.title('Распределение подписок')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Отношение пользователей с подпиской на общее кол-во пользователей ~ 0.46 или 46%

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Супер, именно доля  корректно дает ответ на поставленный вопрос.
# </div>

# %% [markdown]
# 3.3
#
# *Изучим возраст пользователей*

# %%
users['age'].hist(figsize=(10,6),bins=20)
plt.title('Количество пользователей по возрасту ')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
# Out:
# Text(0, 0.5, 'Количество пользователей')

# %% [markdown]
# На общей гистограмме видно примерное распрделение пользователей, теперь "приблизим" ее в диапозон от 20 до 30, являющийся целевой группой

# %%
users['age'].hist(figsize=(10,6),bins=21,range=(20,30))
plt.title('Количество пользователей по возрасту ')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
# Out:
# Text(0, 0.5, 'Количество пользователей')

# %%
users.boxplot('age')
plt.title('Количество пользователей по возрасту ')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
# Out:
# Text(0, 0.5, 'Количество пользователей')

# %%
print('1 квартиль',np.quantile(users['age'], 0.25))
print('1 квартиль',np.quantile(users['age'], 0.5))
print('3 квартиль',np.quantile(users['age'], 0.75))
# Out:
# 1 квартиль 22.0
# 1 квартиль 25.0
# 3 квартиль 28.0

# %% [markdown]
# по второй гистограмме и боксплоту видно, что основная масса пользователей находится в возрасте от 22 до 28 лет

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Также, рекомендую использовать метод describe() для расчета описательных статистик.
# </div>

# %% [markdown]
# 3.4
#
# *Изучим дистанцию за поездку*

# %%
rides['distance'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по дистанции ')
plt.xlabel('Дистанция')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %%
rides['distance'].hist(figsize=(10,6),bins=20,range=(2000,5000))

plt.title('Количество поездок по дистанции ')
plt.xlabel('Дистанция')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %% [markdown]
# По гистрограмме видно, что основная часть пользователей едет от 2500 до 4000 метров за поездку, но существует подгруппа поездок до 1000 метров, когда самокат берут на пару минут

# %% [markdown]
# 3.5
#
# *Изучим длительность поездки*

# %%
rides['duration'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по длительности ')
plt.xlabel('Длительность')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %% [markdown]
# график длительности поездки похож на нормальное распределение с средним значением около 17

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Отлично, двигаемся дальше.
# </div>

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# 4.1*объеденим датафреймы users и rides в rides_detail*

# %%
rides_detail = rides.merge(users, on='user_id')

# %%
rides_detail = rides_detail.merge(subs, on ='subscription_type')

# %%
rides_detail.head()
# Out:
#    user_id     distance   duration       date  date_month  index  name  age  \
# 0        1  4409.919140  25.599769 2021-01-01           1      0  Кира   22
# 1        1  2617.592153  15.816871 2021-01-18           1      0  Кира   22
# 2        1   754.159807   6.232113 2021-04-20           4      0  Кира   22
# 3        1  2694.783254  18.511000 2021-08-11           8      0  Кира   22
# 4        1  4028.687306  26.265803 2021-08-28           8      0  Кира   22
#
#      city subscription_type  minute_price  start_ride_price  subscription_fee
# 0  Тюмень             ultra             6                 0               199
# 1  Тюмень             ultra             6                 0               199
# 2  Тюмень             ultra             6                 0               199
# 3  Тюмень             ultra             6                 0               199
# 4  Тюмень             ultra             6                 0               199

# %%
rides_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   distance           18068 non-null  float64
#  2   duration           18068 non-null  float64
#  3   date               18068 non-null  datetime64[ns]
#  4   date_month         18068 non-null  int64
#  5   index              18068 non-null  int64
#  6   name               18068 non-null  object
#  7   age                18068 non-null  int64
#  8   city               18068 non-null  object
#  9   subscription_type  18068 non-null  object
#  10  minute_price       18068 non-null  int64
#  11  start_ride_price   18068 non-null  int64
#  12  subscription_fee   18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(3)
# memory usage: 1.9+ MB

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     18068 non-null  int64
#  1   distance    18068 non-null  float64
#  2   duration    18068 non-null  float64
#  3   date        18068 non-null  datetime64[ns]
#  4   date_month  18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB

# %%
rides_detail.duplicated().sum()
# Out:
# 0

# %%
rides_detail.drop_duplicates().reset_index()
# Out:
#        level_0  user_id     distance   duration       date  date_month  index  \
# 0            0        1  4409.919140  25.599769 2021-01-01           1      0
# 1            1        1  2617.592153  15.816871 2021-01-18           1      0
# 2            2        1   754.159807   6.232113 2021-04-20           4      0
# 3            3        1  2694.783254  18.511000 2021-08-11           8      0
# 4            4        1  4028.687306  26.265803 2021-08-28           8      0
# ...        ...      ...          ...        ...        ...         ...    ...
# 18063    18063     1534  3781.098080  19.822962 2021-11-04          11   1533
# 18064    18064     1534  2840.423057  21.409799 2021-11-16          11   1533
# 18065    18065     1534  3826.185507  18.435051 2021-11-18          11   1533
# 18066    18066     1534  2902.308661  16.674362 2021-11-27          11   1533
# 18067    18067     1534  2371.711192  15.893917 2021-12-29          12   1533
#
# ...

# %% [markdown]
# в объедененной таблице появились дубликаты, удалим их

# %%
rides_detail.isna().sum()
# Out:
# user_id              0
# distance             0
# duration             0
# date                 0
# date_month           0
# index                0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# в объедененной таблице отсутствуют пропуски

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Замечания:
#
# * Обрати внимание, что нас просят объединить все три таблицы.
#
# * Следует посмотреть исходную размерность датасетов
#
# * После объединения размерность таблицы, к которой присоединяем должна совпадать с исходной.
#
# * Отсутствует проверка на пропуски в объединенном датасете.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# 4.2*создадим датафрейм users_unsub и users_sub для пользователей без подписки и с подпиской соответственно*

# %%
users_unsub = rides_detail.loc[rides_detail['subscription_type'] == 'free']

# %%
users_sub = rides_detail.loc[rides_detail['subscription_type'] == 'ultra']

# %% [markdown]
# 4.3*Визуализируем значения расстояния и длительности поездок для users_unsub и users_sub*

# %%
users_unsub['distance'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по дистанции для unsub')
plt.xlabel('Дистанция')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %%
print('1 квартиль',np.quantile(users_unsub['distance'], 0.25))
print('1 квартиль',np.quantile(users_unsub['distance'], 0.5))
print('3 квартиль',np.quantile(users_unsub['distance'], 0.75))
# Out:
# 1 квартиль 2366.5626893101276
# 1 квартиль 3114.648464847295
# 3 квартиль 3905.6978940544814

# %%
users_sub['distance'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по дистанции для sub')
plt.xlabel('Дистанция') 
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %%
print('1 квартиль',np.quantile(users_sub['distance'], 0.25))
print('1 квартиль',np.quantile(users_sub['distance'], 0.5))
print('3 квартиль',np.quantile(users_sub['distance'], 0.75))
# Out:
# 1 квартиль 2785.4440169631416
# 1 квартиль 3148.6372291760854
# 3 квартиль 3560.574424951713

# %% [markdown]
# Несмотря на то, что медианное значение дистанции в обеих группах практически одинаково, стоит отметить, что 1 и 3 квартили в обеих группах существенно отличаются.
#
# 1 квартиль больше среди пользователей с подпиской, а 3 квартиль больше у людей без подписок

# %%
users_unsub['duration'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по длительности для unsub')
plt.xlabel('Длительность')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %%
print('1 квартиль',np.quantile(users_unsub['duration'], 0.25))
print('1 квартиль',np.quantile(users_unsub['duration'], 0.5))
print('3 квартиль',np.quantile(users_unsub['duration'], 0.75))
# Out:
# 1 квартиль 12.958436576931698
# 1 квартиль 17.326890226082043
# 3 квартиль 21.594070634390352

# %%
users_sub['duration'].hist(figsize=(10,6),bins=20)
plt.title('Количество поездок по длительности для unsub')
plt.xlabel('Длительность')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %%
print('1 квартиль',np.quantile(users_sub['duration'], 0.25))
print('1 квартиль',np.quantile(users_sub['duration'], 0.5))
print('3 квартиль',np.quantile(users_sub['duration'], 0.75))
# Out:
# 1 квартиль 14.524653911131882
# 1 квартиль 18.17815320055055
# 3 квартиль 21.884128697712004

# %% [markdown]
# В двух группах значение 3 квартиля примерно равно. Однаков у пользователей с подпиской 1 и 3 квартиль сдвинут в большую сторону

# %%
rides_detail
# Out:
#        user_id     distance   duration       date  date_month  index     name  \
# 0            1  4409.919140  25.599769 2021-01-01           1      0     Кира
# 1            1  2617.592153  15.816871 2021-01-18           1      0     Кира
# 2            1   754.159807   6.232113 2021-04-20           4      0     Кира
# 3            1  2694.783254  18.511000 2021-08-11           8      0     Кира
# 4            1  4028.687306  26.265803 2021-08-28           8      0     Кира
# ...        ...          ...        ...        ...         ...    ...      ...
# 18063     1534  3781.098080  19.822962 2021-11-04          11   1533  Альберт
# 18064     1534  2840.423057  21.409799 2021-11-16          11   1533  Альберт
# 18065     1534  3826.185507  18.435051 2021-11-18          11   1533  Альберт
# 18066     1534  2902.308661  16.674362 2021-11-27          11   1533  Альберт
# 18067     1534  2371.711192  15.893917 2021-12-29          12   1533  Альберт
#
# ...

# %% [markdown]
# сравнивая две категории можно отметить, что у неподписчиков:
#
# 1)очень большая дисперсия в дистанции(1 квартиль - 2366, 3 - 3903)
# 2)также выше дисперсия и в продолжительнсоти поездок(1 квартиль - 12.9, 3 - 21.5)
#
# у подписчиков:
#
# 1)дисперсия в дистанции меньше(1- 2785, 3- 3559)
# 2)дисперсия в продолжительности также меньше(1 - 14.4, 3 - 21.8)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Визуализация корректная.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Также можно совместить графики распределений для более наглядного сравнения.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Прошу тебя написать более подробный вывод о сравнении профилей двух категорий.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> переделанный отчет снизу

# %% [markdown]
# сравнивая две категории можно отметить, что у неподписчиков:
#
# 1)большой диапазон значений дистанции поездок в основном от 2366 до 3903 метров
#
# 2)большой диапазон значений продолжительности поездок в основном от 12.9 до 21.5 минут
#
#
# у подписчиков:
#
# 1)диапазон дистанции меньше(основная часть от 2785 до 3559 метров)
#
# 2)диапазон длительности поездок меньше(основная часть от 14.4  до 21.8 минут)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Такой вывод не подойдёт — он слишком технический и в то же время не совсем корректный. Ты используешь термин «дисперсия», но приводишь квартильные значения — это разные вещи, и такая подача может запутать. Кроме того, вывод не помогает понять, что всё это значит с точки зрения бизнеса.
#
# Постарайся формулировать выводы проще и понятнее — так, чтобы человек без статистического образования (например, заказчик) сразу понял, в чём разница между категориями и почему это важно. На графиках все видно и нам нужно только это писать и сравнить.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %%
rides_detail['duration'] = np.ceil(rides_detail['duration'])

# %%
ride_counts = rides_detail.groupby(['user_id', 'date_month', 'subscription_type']).size().reset_index(name='ride_count')

# %%
profit = rides_detail.groupby(['user_id', 'date_month', 'subscription_type','minute_price','start_ride_price','subscription_fee']).agg(
    total_distance=('distance', 'sum'),  # сумма дистанций
    total_duration=('duration', 'sum')    # сумма длительностей
).reset_index()

# %%
profit = profit.merge( ride_counts, on=['user_id', 'date_month', 'subscription_type'])

# %%
def price_total(row):
    a=0
    sub_price = row['subscription_fee']
    start_price = row['start_ride_price']
    minute_price = row['minute_price']
    minutes = row['total_duration']
    sub_type = row['subscription_type']
    ride_cnt = row['ride_count']
    
    a = sub_price + (start_price*ride_cnt)+ (minute_price*minutes)
    return a

# %%
profit['total'] = profit.apply(price_total, axis = 1)

# %%
profit
# Out:
#        user_id  date_month subscription_type  minute_price  start_ride_price  \
# 0            1           1             ultra             6                 0
# 1            1           4             ultra             6                 0
# 2            1           8             ultra             6                 0
# 3            1          10             ultra             6                 0
# 4            1          11             ultra             6                 0
# ...        ...         ...               ...           ...               ...
# 11326     1534           6              free             8                50
# 11327     1534           8              free             8                50
# 11328     1534           9              free             8                50
# 11329     1534          11              free             8                50
# 11330     1534          12              free             8                50
#
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Выше исправленный подсчет выручки

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
# Да, теперь верно
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# К сожалению здесь код упал с ошибкой. Поправь, пожалуйста и я буду ждать твой проект на повторное ревью.
#
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Тимур, у тебя в расчётах сразу несколько серьёзных проблем, которые мешают правильно выполнить задачу:
#
#
# * **Ошибка: отсутствие разбивки по месяцам:** Ты сгруппировал данные только по user_id, без учёта месяца. Это противоречит заданию, в котором чётко сказано: все показатели нужно считать по каждому пользователю в каждом месяце. Иначе мы теряем динамику: пользователь мог ездить в разные месяцы по-разному — и выручка, и активность в месяцах могла меняться. Нужно группировать не просто по пользователю, а по паре: user_id + месяц. Это позволит посчитать все показатели отдельно за каждый месяц, как требует условие.
#
#
# * **Ошибка: неправильное округление длительности поездок:** Ты округлил уже агрегированную (суммарную) длительность поездок. Но в задании указано, что округлять нужно каждую поездку отдельно, прежде чем она попадёт в расчёт выручки. Округление общей суммы — это математически неверно и даёт искажённый результат, особенно при большом числе поездок. Каждая отдельная поездка должна быть округлена вверх, до целого числа минут. Только после этого можно суммировать длительность по месяцам.
#
#
# * **Ошибка: расчёт выручки:** Ты не реализовал расчёт выручки по формуле из задания. Нет учёта стоимости старта, стоимости минуты и подписки. Без этого нельзя говорить о помесячной выручке, которая является основной метрикой на этом этапе проекта. Нужно рассчитать выручку по каждой строке, исходя из всех трёх компонентов: стоимость старта * количество поездок + стоимость минуты * суммарную длительность + абонплата (если есть). И всё это — за каждый месяц для каждого пользователя.
#
#
# * **Ошибка: лишние преобразования, дубли и усложнение:** В твоём решении слишком много лишних промежуточных таблиц и джойнов. Много действий, но они не приближают к цели. Это делает логику не только запутанной, но и уязвимой к ошибкам. Достаточно одной чёткой группировки по пользователю и месяцу, где агрегируются нужные поля. В этом агрегате уже можно использовать значения из тарифов и провести расчёты. Всё просто и читаемо.
#
#
# </div>

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %%
from scipy import stats as st

# %% [markdown]
# 6.1*Проверим гипотезу о "выгодности" пользователей с подпиской*

# %% [markdown]
# Сформулируем гипотезы о "выгодности" пользователей с подпиской.
#
# Нулевая гипотеза (H₀): среднее время поездки у подписчиков не больше, чем у пользователей без подписки.
#
# Альтернативная гипотеза (H₁): среднее время поездки у подписчиков больше.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# ✍
# Такая формулировка гипотез — некорректна, потому что она не отражает то, что ты реально проверяешь статистически.
#
# В чём ошибка: Ты говоришь о выгоде, но в данных нет прямой метрики «выгоды». Задание просит проверить, тратят ли подписчики больше времени на поездку. А значит, гипотезы должны быть именно про среднюю продолжительность поездок, а не про «выгодность».
#
#
# Как правильно: Формулировка должна быть конкретной и измеримой:
#
# * Нулевая гипотеза (H₀): среднее время поездки у подписчиков не больше, чем у пользователей без подписки.
#
# * Альтернативная гипотеза (H₁): среднее время поездки у подписчиков больше.
#
# Так ты будешь проверять именно то, что заложено в задаче — и к чему можно применить статистический тест. А понятие «выгоды» — это уже бизнес-интерпретация, которую можно обсуждать после проверки гипотезы, на основе результатов.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.4</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# К сожалению не сформулированы нулевая и альтернативная гипотезы.
# </div>

# %%
users_sub_duration = users_sub['duration']

# %%
users_unsub_duration = users_unsub['duration']

# %%
print(f'среднее значение продолжительности с подпиской {np.mean(users_sub_duration)}')
print(f'среднее значение продолжительности без подписки {np.mean(users_unsub_duration)}')
# Out:
# среднее значение продолжительности с подпиской 18.54198516280583
# среднее значение продолжительности без подписки 17.39090929866399

# %%
res_duration = st.ttest_ind(
users_sub_duration,
users_unsub_duration,
alternative = 'greater',
equal_var = False
)
print('значение p-value', res_duration.pvalue,'\n')

p =0.05

if res_duration.pvalue< p:
    print('отвергаем нулевую гипотезу')
else:
    print('не отвергаем нулевую гипотезу')
# Out:
# значение p-value 5.6757813771289775e-37
#
# отвергаем нулевую гипотезу

# %% [markdown]
# Действительно, можно утверждать о том, что пользователи с подпиской имеют более долгие поездки

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Ты пишешь: if p > p-value: отвергаем нулевую, а должно быть наоборот: если p-value < уровень значимости — только тогда отвергаем H₀. Иначе ты можешь случайно отклонить гипотезу, даже когда для этого нет оснований.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# ✍
# Уже лучше, но выбранный тобой уровень значимости p = 0.1 — слишком высокий для такой задачи. Это значит, что ты готов принять 10% шанс ошибочного вывода, что неприемлемо в большинстве аналитических задач.
#
# Обычно в прикладной аналитике используется уровень значимости 0.05 или 0.01, чтобы уменьшить риск ложных выводов.
#
# Использовать 0.1 можно только в случае, если это обосновано заранее (например, при экспериментальном анализе с высокой степенью допущения), но в данном случае это выглядит как ошибка. Лучше использовать стандартное значение 0.05, чтобы выводы были надёжнее и не вызывали вопросов. Это относится ко всем тестам.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.4</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# 6.2*Проверим гипотезу о не превышении 3130 метров за поездку у пользователей с подпиской*

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Также нет гипотез
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы

# %% [markdown]
# Нулевая гипотеза - пользователи проезжают около 3130 метров за поездку с подпиской
#
# Альтернативная гипотеза - дистанция превышает 3130 метров

# %%
users_sub_distance = users_sub['distance']

# %%
print(f'среднее значение дистанции с подпиской {np.mean(users_sub_distance)}')
# Out:
# среднее значение дистанции с подпиской 3115.4453880370247

# %%
value = 3130

# %%
res_distance = st.ttest_1samp(
users_sub_distance, value, alternative='greater'
    
)
print('значение p-value', res_distance.pvalue,'\n')

p=0.05

if res_distance.pvalue< p:
    print('отвергаем нулевую гипотезу')
else:
    print('не отвергаем нулевую гипотезу')
# Out:
# значение p-value 0.9195368847849785
#
# не отвергаем нулевую гипотезу

# %% [markdown]
# Можно утверждать, что в среднем поездки у пользователей с подпиской около 3130 метров

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> переделано

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Замечания:
#
#
# 1. Ты проверяешь гипотезу two-sided, то есть: отличается ли среднее расстояние в любую сторону от 3130. А вопрос задачи — превышает ли среднее 3130, то есть нужен односторонний тест с alternative='greater'. Что это значит: твой тест не даёт ответа на вопрос, действительно ли пользователи ездят дальше допустимого. Это односторонний тест и необходимо использовать
#
#
# 2. Аналогично про  if p > p-value
#
#
# 3. Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального" и соответственно в статистическом тесте использовать параметр <code>alternative = 'greater'</code>
#
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# 6.3*Проверим гипотезу о том будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки*

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Нет гипотез
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы

# %% [markdown]
# Нулевая гипотеза - выручки с подписчиков и неподписчиков равны
#
# Альтернативная гипотеза - выручка с пользователей с подпиской выше

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# добавим в датафрейм df_profit стобец с помесячной выручкой

# %%
users_sub_permonth = profit.loc[profit['subscription_type'] == 'ultra','total']

# %%
users_unsub_permonth = profit.loc[profit['subscription_type'] == 'free','total']

# %%
print(f'среднее значение выручки в месяц с подпиской {np.mean(users_sub_permonth)}')
print(f'среднее значение выручки в месяц без подписки {np.mean(users_unsub_permonth)}')
# Out:
# среднее значение выручки в месяц с подпиской 362.7921906022502
# среднее значение выручки в месяц без подписки 328.6413651073845

# %%
res_duration = st.ttest_ind(
users_sub_permonth,
users_unsub_permonth,
alternative = 'greater',
equal_var = False
)
print('значение p-value', res_duration.pvalue,'\n')

p =0.05

if res_duration.pvalue < p :
    print('отвергаем нулевую гипотезу')
else:
    print('не отвергаем нулевую гипотезу')
# Out:
# значение p-value 8.874140893976874e-40
#
# отвергаем нулевую гипотезу

# %% [markdown]
# Можно утверждать, что выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Все расчеты нам необходимо сделать в предыдущем шаге при создании таблицы с помесячной выручкой, здесь они лишние и тольк омогут запутать.
#
# Аналогично про if p > p-value
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# 6.4

# %% [markdown]
# Нам понадобиться использовать st.ttest_rel(), т.к выборки зависимые и состоят из тех же пользователей до и после внедрения новых серверов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> в этом тесте нужно использовать одностороннюю гипотезу с 'less', т.к ожидается спад обращений
#
# Нулевая гипотеза - количество обращений останется прежним
#
# Альтернативная гипотеза - количество обращений уменьшиться

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# ✍
# Вопрос: какую гипотезу мы будем проверять - одностороннюю или двустороннюю и какие гипотезы мы можем сформулировать?
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# 👍
# Верно
# </div>

# %% [markdown]
# Общий вывод:
#
# На основе исследования сервиса аренды самокатов GoFast можно обозначить ключевые шаги:
#
# 1) в таблице с пользователями хранились дубликаты в количестве **31**(значения полученные по ошибке)
#
# 2) по итогам исследовательского анализа узнали процент пользователей с подпиской - **46%**, средний возраст пользователей - **25**, город с наибольшим количеством пользователей - Пятигорск(**226**), наименьшим - Москва(**172**). Из этого следует сделать вывод о том, что нужно выделять больше денег на продвижение сервиса в столице и увеличивать свою долю рынка там
#
# 3)  Распределения расстояний и времени поездок показали, что пользователи без подписки совершают более разнородные поездки: у них больше коротких и экстремально длинных поездок**(в основном от 2366 до 3905 метров для дистанции и и от 12.9 до 21.5 минут для длительности поездки)**. У подписчиков поведение более стабильное и предсказуемое, что может упростить планирование ресурсов и персонализированных предложений**(для дистанции 2785 и 3560 метров и  14.5 до 21.8 минут времени поездки)**.
#
# 4) Была создана таблица, группирующая клиентов по месяцам и функция которая считает в этой таблице месячную выручку. С помощью этой таблицы стало намного удобнее видеть динамику и сравнивать доходы, группируя данные по месяцам.
#
# 5) На основне выдвинутых гипотез и работы с распределением можно сделать выводы о том:
#
#     5.1) Выдвинув нулевую гипотезу о том, что среднее время поездки у подписчиков не больше, чем у пользователей без подписки мы не смогли опровергнуть ее, что дает нам полагать то, что время поездки у подписчиков больше
#
#     5.2)Выдвинув гипотезу о том, что в среднем поездки у пользователей с подпиской не более 3130 метров был проведен t-тест на основне которого можно утверждать о том, что пользователи проезжать около 3130 метров
#
#     5.3) выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки
#
# 6) На основне различных исследований можно сделать вывод о том, что пользователи с подпиской ultra более стабильны и предсказуемы, а также приносят больше прибыли, чем пользователи без подписки.
#
# 7) Сейчас уровень подписчиков равен 46 процентам, следует предложить пользователям без подписки пробную версию для привлечения потенциальных подписчиков

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> вывод переделал

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Для заказчика будет понятней, если расписать общий вывод по пунктам <b>всей</b> проделанной работы, что бы он понимал за что платит деньги. Здесь, в финальном выводе требуется максимально подробно и с цифрами описать все те инсайды в данных, которые были обнаружены в ходе выполнения проекта.
#
# Давай расширим общий вывод, не стоит скупиться на слова, ведь работа выполнена на хорошем уровне и написать есть что.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.3</b><br><br>
# ✍
# Хорошо, что ты добавил структурированный общий вывод — это уже лучше. Но сейчас он выглядит как просто список того, что ты делал, а не осмысленное подведение итогов проекта. В таком виде заказчику будет сложно понять, что именно ты обнаружил, чем это полезно, и почему это важно для бизнеса.
#
# Каждый пункт должен не просто сообщать факт, а объяснять, что он значит, на какие действия намекает, и как это влияет на прибыль или стратегию сервиса. И главное — старайся подкреплять выводы цифрами: если что-то «выше» или «дольше» — покажи на сколько именно.
#
#
# Пример, как можно переформулировать один из пунктов:
#
# Было:
#
#     3) визуализировав данные мы узнали, что диапазон значений у неподписчиков для дистанции и для длительности поездки выше, чем у подписчиков
#
# Можно так:
#
#     Распределения расстояний и времени поездок показали, что пользователи без подписки совершают более разнородные поездки: у них больше коротких и экстремально длинных поездок. У подписчиков поведение более стабильное и предсказуемое, что может упростить планирование ресурсов и персонализированных предложений. И подкрепить конкретными цифрами.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.1</b><br><br>
# Тимур, хорошая работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, видны последовательность и вдумчивость.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.2</b><br><br>
# Тимур, спасибо, что прислал работу на повторное ревью. По проекту осталось несколько моментов, которые требуют твоего внимания. Прошу тебя не торопиться, внимательно прочитать мои комментарии и внести правки. Буду ждать твой проект на ревью.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.3</b><br><br>
# Тимур, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# #### Шаг 7. Распределения
